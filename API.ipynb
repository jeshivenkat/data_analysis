# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8af76ab8-4292-4377-8132-27f9fcce91c3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:17:02.236Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 2436, 'name': '2levkoxkhmn', 'symbol': 'b7ls1e2zyik', 'slug': '4n8x626nmmg', 'cmc_rank': 6550, 'num_market_pairs': 6003, 'circulating_supply': 9824, 'total_supply': 3276, 'max_supply': 2497, 'infinite_supply': None, 'last_updated': '2024-02-20T06:17:02.236Z', 'date_added': '2024-02-20T06:17:02.236Z', 'tags': ['fotnf6dlkf7', 'yk797pmzm6l', 'ua1blirdjd', '1r2b7wb6fcph', 'svq27lyible', 'zoim28w18', 'gvnjhck4p7', '3ovlr7sq51k', 's1w8pzzuj2d', 'p1mxfo3vzbb'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.44305980393581734, 'volume_24h': 196, 'volume_change_24h': 0.558097240839361, 'percent_change_1h': 0.9477828114751166, 'percent_change_24h': 0.7391028112242033, 'percent_change_7d': 0.22047787527327833, 'market_cap': 0.967665606637234, 'market_cap_dominance
# ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com./v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8af76ab8-4292-4377-8132-27f9fcce91c3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:12:51.440Z', 'error_code': 0, 'error_message': None, 'elapsed': 188, 'credit_count': 3, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#         id              name  symbol                  slug  num_market_pairs  \
# 0        1           Bitcoin     BTC               bitcoin             10821
# 1     1027          Ethereum     ETH              ethereum              8428
# 2      825       Tether USDt    USDT                tether             74897
# 3     1839               BNB     BNB                   bnb              2070
# 4     5426            Solana     SOL                solana               626
# ..     ...               ...     ...                   ...               ...
# 495   9176  RocketX exchange     RVF  rocket-vault-rocketx                64
# 496  19055   Solidus Ai Tech  AITECH       solidus-ai-tech                45
# 497   3884        Function X      FX            function-x                30
# 498   3437         ABBC Coin    ABBC             abbc-coin                89
# 499   3661  Stronghold Token     SHX      stronghold-token                30
#
#                    date_added  \
# ...

# %%
import requests#without api key

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/87.jpg

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9e810cb095e33785376312dbed3c6938',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T08:35:15.825Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8886, 'name': 're2mrjr1nd9', 'symbol': 'un45ukweeid', 'slug': 'lmqilqcsq4p', 'cmc_rank': 336, 'num_market_pairs': 639, 'circulating_supply': 7054, 'total_supply': 2691, 'max_supply': 1586, 'infinite_supply': None, 'last_updated': '2024-02-20T08:35:15.825Z', 'date_added': '2024-02-20T08:35:15.825Z', 'tags': ['jdcdb1566m', 'wju7rkgixbd', 'gv3vuh3il4g', '4jrox9u9um6', 'mav6xh2dtgm', '3ofbhyp9hpj', 'tk04ya3fn8j', '1n1gnjw38ky', 'mtz174xaclk', 'u73aj5d1pep'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.4002747622412841, 'volume_24h': 5083, 'volume_change_24h': 0.8721941985099173, 'percent_change_1h': 0.9693919681182104, 'percent_change_24h': 0.4571285818778026, 'percent_change_7d': 0.7069373400116523, 'market_cap': 0.7090669220682508, 'market_cap_dominanc
# ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com./v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9e810cb095e33785376312dbed3c6938',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T08:35:21.468Z', 'error_code': 1001, 'error_message': 'This API Key is invalid.', 'elapsed': 0, 'credit_count': 0}}

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=260b5bc45c64414e67ff229ff9423e0a'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9e810cb095e33785376312dbed3c6938',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1708419600, 'main': {'temp': 265.06, 'feels_like': 259.4, 'temp_min': 265.06, 'temp_max': 265.88, 'pressure': 1030, 'sea_level': 1030, 'grnd_level': 1010, 'humidity': 91, 'temp_kf': -0.82}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.5, 'deg': 191, 'gust': 6.27}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 09:00:00'}, {'dt': 1708430400, 'main': {'temp': 266.05, 'feels_like': 260.29, 'temp_min': 266.05, 'temp_max': 268.02, 'pressure': 1029, 'sea_level': 1029, 'grnd_level': 1009, 'humidity': 90, 'temp_kf': -1.97}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.84, 'deg': 184, 'gust': 7.31}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 12:00:00'}, {'dt': 1708441200, 'main': {'temp': 265.23, 'fe
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['list'])

# %%
norm
# Out:
#             dt                                            weather  visibility  \
# 0   1708419600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1708430400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 2   1708441200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 3   1708452000  [{'id': 804, 'main': 'Clouds', 'description': ...        9777
# 4   1708462800  [{'id': 804, 'main': 'Clouds', 'description': ...        7943
# 5   1708473600  [{'id': 804, 'main': 'Clouds', 'description': ...        9399
# 6   1708484400  [{'id': 804, 'main': 'Clouds', 'description': ...        9659
# 7   1708495200  [{'id': 804, 'main': 'Clouds', 'description': ...        4796
# 8   1708506000  [{'id': 600, 'main': 'Snow', 'description': 'l...         437
# 9   1708516800  [{'id': 600, 'main': 'Snow', 'description': 'l...         568
# 10  1708527600  [{'id': 600, 'main': 'Snow', 'description': 'l...         412
# ...
